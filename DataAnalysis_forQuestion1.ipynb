# %%
#importing libraries
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as st
import numpy as np

# %%
data_by_state =pd.read_excel('Data/Table 3. Retail turnover, by state 850103.xlsx',sheet_name="Data1")
data_by_state = data_by_state.drop(range(0,9))
data_by_state = data_by_state.rename(columns = {'Unnamed: 0':'Month'})
data_by_state.head()
# Out:
#                   Month Turnover ;  New South Wales ;  Total (Industry) ;  \
# 9   1982-04-01 00:00:00                                            1250.2
# 10  1982-05-01 00:00:00                                              1300
# 11  1982-06-01 00:00:00                                            1234.2
# 12  1982-07-01 00:00:00                                              1265
# 13  1982-08-01 00:00:00                                            1217.6
#
#    Turnover ;  Victoria ;  Total (Industry) ;  \
# 9                                       916.2
# 10                                      931.2
# 11                                        887
# 12                                      921.3
# 13                                      883.2
#
#    Turnover ;  Queensland ;  Total (Industry) ;  \
# 9                                         486.3
# 10                                        492.8
# 11                                        494.1
# ...

# %%
#Filters data from January 2013 to last date September 2023
data_by_state = data_by_state.drop(range(9,378))
data_by_state
# Out:
#                    Month Turnover ;  New South Wales ;  Total (Industry) ;  \
# 378  2013-01-01 00:00:00                                            6647.5
# 379  2013-02-01 00:00:00                                            5927.2
# 380  2013-03-01 00:00:00                                            6531.4
# 381  2013-04-01 00:00:00                                              6340
# 382  2013-05-01 00:00:00                                            6542.1
# ..                   ...                                               ...
# 502  2023-05-01 00:00:00                                           10996.4
# 503  2023-06-01 00:00:00                                           10677.2
# 504  2023-07-01 00:00:00                                           10595.3
# 505  2023-08-01 00:00:00                                           10757.9
# 506  2023-09-01 00:00:00                                           10997.8
#
#     Turnover ;  Victoria ;  Total (Industry) ;  \
# ...

# %%
question_1  = data_by_state.iloc[:, 10:18]
question_1.insert(0,"Month",data_by_state['Month'],True)
question_1.head()
# Out:
#                    Month Turnover ;  New South Wales ;  Total (Industry) ;.1  \
# 378  2013-01-01 00:00:00                                             6650.3
# 379  2013-02-01 00:00:00                                             6751.9
# 380  2013-03-01 00:00:00                                             6711.6
# 381  2013-04-01 00:00:00                                             6743.6
# 382  2013-05-01 00:00:00                                             6740.4
#
#     Turnover ;  Victoria ;  Total (Industry) ;.1  \
# 378                                       5366.4
# 379                                       5406.3
# 380                                       5383.5
# 381                                       5366.3
# 382                                       5409.7
#
#     Turnover ;  Queensland ;  Total (Industry) ;.1  \
# 378                                         4554.5
# 379                                         4643.2
# 380                                         4578.2
# ...

# %%
question_1.plot(x='Month')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
population_data =pd.read_excel('Data/Australian Population data.xlsx',sheet_name="Data1")
population_data = population_data.drop(range(0,9))
population_data = population_data.rename(columns = {'Unnamed: 0':'Month'})
population_data.head()
# Out:
#                   Month  \
# 9   1981-06-01 00:00:00
# 10  1981-09-01 00:00:00
# 11  1981-12-01 00:00:00
# 12  1982-03-01 00:00:00
# 13  1982-06-01 00:00:00
#
#    Estimated Resident Population ;  Male ;  New South Wales ;  \
# 9                                             2608351
# 10                                            2616060
# 11                                            2624579
# 12                                            2634534
# 13                                            2643527
#
#    Estimated Resident Population ;  Male ;  Victoria ;  \
# 9                                             1958717
# 10                                            1964139
# 11                                            1969349
# 12                                            1975617
# 13                                            1981619
#
#    Estimated Resident Population ;  Male ;  Queensland ;  \
# 9                                             1178447
# ...

# %%
#Filters data from January 2013 to last date September 2023
population_data = population_data.drop(range(9,136))
population_data.head()
# Out:
#                    Month  \
# 136  2013-03-01 00:00:00
# 137  2013-06-01 00:00:00
# 138  2013-09-01 00:00:00
# 139  2013-12-01 00:00:00
# 140  2014-03-01 00:00:00
#
#     Estimated Resident Population ;  Male ;  New South Wales ;  \
# 136                                            3664409
# 137                                            3674410
# 138                                            3687294
# 139                                            3698220
# 140                                            3714264
#
#     Estimated Resident Population ;  Male ;  Victoria ;  \
# 136                                            2842811
# 137                                            2856419
# 138                                            2871393
# 139                                            2884387
# 140                                            2902774
#
#     Estimated Resident Population ;  Male ;  Queensland ;  \
# 136                                            2310867
# ...

# %%
state_population = population_data.iloc[:, 19:27]
state_population.insert(0,"Month",population_data['Month'],True)
state_population.head()
# Out:
#                    Month  \
# 136  2013-03-01 00:00:00
# 137  2013-06-01 00:00:00
# 138  2013-09-01 00:00:00
# 139  2013-12-01 00:00:00
# 140  2014-03-01 00:00:00
#
#     Estimated Resident Population ;  Persons ;  New South Wales ;  \
# 136                                            7382957
# 137                                            7404032
# 138                                            7430904
# 139                                            7454938
# 140                                            7487834
#
#     Estimated Resident Population ;  Persons ;  Victoria ;  \
# 136                                            5744915
# 137                                            5772669
# 138                                            5804499
# 139                                            5832585
# 140                                            5869511
#
#     Estimated Resident Population ;  Persons ;  Queensland ;  \
# 136                                            4634430
# ...

# %%
state_population.plot(x='Month')
plt.legend(bbox_to_anchor=(1.04, 1), loc="upper left")
plt.show()

# %%
latest_population = state_population.iloc[-1,1:9]
latest_population = pd.to_numeric(latest_population, errors='coerce')
latest_turnover = pd.to_numeric(question_1.iloc[-7,1:9], errors='coerce')
latest_turnover = latest_turnover*1000000

turnover_per_person =  latest_turnover.values / latest_population.values

states = ['NSW', 'VIC', 'QLD', 'SA', 'WA', 'TAS', 'NT', 'ACT']
plt.bar(states,turnover_per_person, width = 0.5)
plt.ylim(1200,1450)
plt.xlabel('Australian States')
plt.ylabel("Retail Turnover per Person (in AUD)")
plt.title('Retail Turnover per person vs State')
plt.show()
